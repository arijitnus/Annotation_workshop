# %% [markdown]
# # Genome Annotation Tools Demo
# This notebook demonstrates usage of QUAST, Prokka, and KofamScan.

# %%
# !quast --version
# !prokka --version
# !exec_annotation -h  # kofamscan main command

# %% [markdown]
# ## Upload and Analyze Files
# Upload assembly or genome files and analyze using the tools.
